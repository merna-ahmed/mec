# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style('whitegrid')
sns.set_palette('RdBu')

# %%
df=pd.read_excel('C:/Users/Merna Ahmed/Downloads/Copy of Coffee Shop Sales.xlsx')
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df.shape
# Out:
# (149116, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  datetime64[ns]
#  2   transaction_time  149116 non-null  object
#  3   transaction_qty   149116 non-null  int64
#  4   store_id          149116 non-null  int64
#  5   store_location    149116 non-null  object
#  6   product_id        149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   product_category  149116 non-null  object
#  9   product_type      149116 non-null  object
#  10  product_detail    149116 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 12.5+ MB

# %%
df.isna().sum()
# Out:
# transaction_id      0
# transaction_date    0
# transaction_time    0
# transaction_qty     0
# store_id            0
# store_location      0
# product_id          0
# unit_price          0
# product_category    0
# product_type        0
# product_detail      0
# dtype: int64

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
df.describe()
# Out:
#        transaction_id               transaction_date  transaction_qty  \
# count   149116.000000                         149116    149116.000000
# mean     74737.371872  2023-04-15 11:50:32.173609984         1.438276
# min          1.000000            2023-01-01 00:00:00         1.000000
# 25%      37335.750000            2023-03-06 00:00:00         1.000000
# 50%      74727.500000            2023-04-24 00:00:00         1.000000
# 75%     112094.250000            2023-05-30 00:00:00         2.000000
# max     149456.000000            2023-06-30 00:00:00         8.000000
# std      43153.600016                            NaN         0.542509
#
#             store_id     product_id     unit_price
# count  149116.000000  149116.000000  149116.000000
# mean        5.342063      47.918607       3.382219
# min         3.000000       1.000000       0.800000
# 25%         3.000000      33.000000       2.500000
# 50%         5.000000      47.000000       3.000000
# ...

# %%
df.describe(include=object)
# Out:
#        transaction_time  store_location product_category     product_type  \
# count            149116          149116           149116           149116
# unique            25762               3                9               29
# top            09:31:15  Hell's Kitchen           Coffee  Brewed Chai tea
# freq                 41           50735            58416            17183
#
#              product_detail
# count                149116
# unique                   80
# top     Chocolate Croissant
# freq                   3076

# %%
df['store_location'].value_counts()
# Out:
# store_location
# Hell's Kitchen     50735
# Astoria            50599
# Lower Manhattan    47782
# Name: count, dtype: int64

# %%
df['store_location'].max()
# Out:
# 'Lower Manhattan'

# %%
df['product_detail'].max()
# Out:
# 'Traditional Blend Chai Rg'

# %%
df['store_location'].value_counts().plot.bar()
xlabel='store_location'

# %%
sns.set()
plt.figure(figsize=(6,6))
sns.displot(df['store_location'])
plt.xticks(rotation=90)
plt.show()

# %%
df['store_location'].unique()
# Out:
# array(['Lower Manhattan', "Hell's Kitchen", 'Astoria'], dtype=object)

# %%
df['product_category'].value_counts()
# Out:
# product_category
# Coffee                58416
# Tea                   45449
# Bakery                22796
# Drinking Chocolate    11468
# Flavours               6790
# Coffee beans           1753
# Loose Tea              1210
# Branded                 747
# Packaged Chocolate      487
# Name: count, dtype: int64

# %%
df['product_category'].max()
# Out:
# 'Tea'

# %%
df['product_category'].unique()
# Out:
# array(['Coffee', 'Tea', 'Drinking Chocolate', 'Bakery', 'Flavours',
#        'Loose Tea', 'Coffee beans', 'Packaged Chocolate', 'Branded'],
#       dtype=object)

# %%
df['product_detail'].value_counts()
# Out:
# product_detail
# Chocolate Croissant             3076
# Earl Grey Rg                    3053
# Dark chocolate Lg               3029
# Morning Sunrise Chai Rg         3026
# Columbian Medium Roast Rg       3013
#                                 ...
# Jamacian Coffee River            146
# Earl Grey                        142
# Guatemalan Sustainably Grown     134
# Spicy Eye Opener Chai            122
# Dark chocolate                   118
# Name: count, Length: 80, dtype: int64

# %%
df.sample(5)
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 127315          127652       2023-06-12         14:03:06                1
# 112270          112528       2023-05-30         10:25:14                3
# 96217            96471       2023-05-15         16:18:30                1
# 59338            59449       2023-04-06         15:18:55                2
# 69932            70102       2023-04-18         14:17:11                1
#
#         store_id   store_location  product_id  unit_price    product_category  \
# 127315         8   Hell's Kitchen          71        3.75              Bakery
# 112270         5  Lower Manhattan          26        3.00              Coffee
# 96217          5  Lower Manhattan          73        3.75              Bakery
# 59338          5  Lower Manhattan          31        2.20              Coffee
# 69932          3          Astoria          59        4.50  Drinking Chocolate
#
#                  product_type       product_detail
# ...

# %%
groupy1=df.groupby('product_category')['unit_price'].max().to_frame()
groupy1
# Out:
#                     unit_price
# product_category
# Bakery                    5.63
# Branded                  28.00
# Coffee                    4.25
# Coffee beans             45.00
# Drinking Chocolate        4.75
# Flavours                  0.80
# Loose Tea                10.95
# Packaged Chocolate       13.33
# Tea                       4.00

# %%
df["Total Revenue"] = df["transaction_qty"] * df["unit_price"]
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df['Total Revenue'].max()
# Out:
# np.float64(360.0)

# %%
df.groupby('product_type')['Total Revenue'].max().to_frame()
# Out:
#                        Total Revenue
# product_type
# Barista Espresso               17.00
# Biscotti                        7.00
# Black tea                       8.95
# Brewed Black tea                9.00
# Brewed Chai tea                12.00
# Brewed Green tea                9.00
# Brewed herbal tea               9.00
# Chai tea                       10.95
# Clothing                       28.00
# Drinking Chocolate             13.33
# Drip coffee                     9.00
# Espresso Beans                 20.45
# Gourmet Beans                  21.00
# Gourmet brewed coffee          10.50
# Green beans                    10.00
# Green tea                       9.25
# Herbal tea                      8.95
# Hot chocolate                  14.25
# House blend Beans              18.00
# Housewares                     72.00
# Organic Beans                  36.00
# Organic Chocolate               7.60
# Organic brewed coffee          10.50
# Pastry                          7.50
# ...

# %%
sns.barplot(x='product_type',y='Total Revenue',data=df )
plt.title('Total Revenue for each Product Type')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x='product_category',y='Total Revenue',data=df )
plt.title('Total Revenue for each Product Category')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.set()
plt.figure(figsize=(6,6))
sns.displot(df['product_category'])
plt.xticks(rotation=90)
plt.show()

# %%
df['transaction_qty'].duplicated().any()
# Out:
# np.True_

# %%
df['Year']=df['transaction_date'].dt.year
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df['Month']=df['transaction_date'].dt.month_name()
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df['Transaction_Day']=df['transaction_date'].dt.day_name()
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
groupytrans=df.groupby('product_category')['Month'].max().to_frame()
groupytrans
# Out:
#                    Month
# product_category
# Bakery               May
# Branded              May
# Coffee               May
# Coffee beans         May
# Drinking Chocolate   May
# Flavours             May
# Loose Tea            May
# Packaged Chocolate   May
# Tea                  May

# %%
df['Month'].max()
# Out:
# 'May'

# %%
df['Transaction_Day'].value_counts()
# Out:
# Transaction_Day
# Friday       21701
# Thursday     21654
# Monday       21643
# Wednesday    21310
# Tuesday      21202
# Sunday       21096
# Saturday     20510
# Name: count, dtype: int64

# %%
sns.boxplot(x='Transaction_Day',y='unit_price',data=df )
plt.title('transaction day for unit price ')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.set()
plt.figure(figsize=(6,6))
sns.displot(df['Month'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.set()
plt.figure(figsize=(6,6))
sns.displot(df['Transaction_Day'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.kdeplot(df["transaction_date"])
plt.show()

# %%
df.to_csv('C:/Users/Merna Ahmed/Downloads/Copy of Coffee Shop Sales edit.xlsx')
